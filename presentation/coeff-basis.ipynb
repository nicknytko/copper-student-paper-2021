# %%
import numpy as np
import numpy.linalg as la
import matplotlib.pyplot as plt

# %%
N = 32
x = np.linspace(-1,1,N)
k1 = np.ones_like(x) * 1
k2 = np.random.rand(N) * 2
k3 = np.cos(np.pi * x * 2)*0.9 + 1
alphas = np.ones(6) / 3
alphas[5] = 0.5

# %%
#plt.plot(x,k1,'o-')
plt.plot(x,k3,'o-')
#plt.plot(x,k3,'o-')
#plt.plot(x,np.abs(alphas[0] * x + alphas[1] * x**2 + alphas[2] * x**3 - alphas[3] * x**4 + alphas[4] * x**5) + alphas[5],'o-')
plt.ylim(0,2)
# Out:
# (0.0, 2.0)
